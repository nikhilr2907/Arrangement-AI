# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import sys
import pathlib

# Add project root to Python path
project_root = pathlib.Path(os.getcwd()).parent
sys.path.insert(0, str(project_root))

from src.audio_training_breakdown_automation.audio_breakdown import run

# %%
stem_path = r"C:\Users\nikhi\ml_projects\Audio_Samples\Focus\melody stems"

# %%
file_paths = [os.path.join(stem_path, f) for f in os.listdir(stem_path)]

# %%
run(file_paths, tempo=75, use_manual_tempo=True)
# Out:
# focus_Arcade #3: Using manual tempo = 75.0 BPM, 258 beats
# focus_Arcade #4: Using manual tempo = 75.0 BPM, 258 beats
# focus_Arcade: Using manual tempo = 75.0 BPM, 258 beats
# focus_Kontakt Portable x64 #2: Using manual tempo = 75.0 BPM, 258 beats
# focus_Kontakt Portable x64 #6: Using manual tempo = 75.0 BPM, 258 beats
# focus_Kontakt Portable x64: Using manual tempo = 75.0 BPM, 258 beats
# focus_Mini V3 #2: Using manual tempo = 75.0 BPM, 258 beats
# focus_Mini V3 #2_2: Using manual tempo = 75.0 BPM, 258 beats
# focus_Omnisphere #2: Using manual tempo = 75.0 BPM, 258 beats
# focus_Omnisphere #3: Using manual tempo = 75.0 BPM, 258 beats
# focus_Omnisphere #4: Using manual tempo = 75.0 BPM, 258 beats
# focus_Omnisphere #5: Using manual tempo = 75.0 BPM, 258 beats
# focus_Omnisphere #6: Using manual tempo = 75.0 BPM, 258 beats
# focus_Piano V2 #2: Using manual tempo = 75.0 BPM, 258 beats
# focus_Piano V2: Using manual tempo = 75.0 BPM, 259 beats
# focus_RNB piano - 2022-Sep-07_3: Using manual tempo = 75.0 BPM, 258 beats
# Processed 7 stems into bars.
# Identified 7 melodic stems and 0 harmony stems.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 run(file_paths, tempo=75, use_manual_tempo=True)
#
# File c:\Users\nikhi\ml_projects\rearrangement_project\src\audio_training_breakdown_automation\audio_breakdown.py:206, in run(stem_paths, tempo, use_manual_tempo)
#     204 print(f"Identified {len(melodic_stems)} melodic stems and {len(harmony_stems)} harmony stems.")
#     205 # Step 3: Process melodic and harmony groups into feature vectors
# --> 206 overall_vectors = process_melodic_harmony_groups(melodic_stems, harmony_stems, BARS)
#     207 print(f"Processed overall vectors for {len(overall_vectors)} time steps.")
#     208 # Step 4: Convert to feature matrices
#
# File c:\Users\nikhi\ml_projects\rearrangement_project\src\audio_training_breakdown_automation\audio_breakdown.py:14, in process_melodic_harmony_groups(melodic_stems, harmony_stems, BARS)
#      11 from src.model_preprocessing.vector_quantisation import vector_quantisation
#      12 from src.model_preprocessing.chunking_transformation import chunking_transformation
# ---> 14 def process_audio_stems(
#      15     stems: List[str],
#      16     tempo_hint: float = None,
#      17     use_manual_tempo: bool = True
#      18 ) -> Dict[str, np.ndarray]:
#      19     """
#      20     Process audio stems into bars with filename tracking.
#      21
#    (...)     26                          instead of using beat tracking (most accurate when tempo is known)
#      27     """
#      28     # Load audio files with sample rate
#
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 1 dimensions. The detected shape was (3,) + inhomogeneous part.
