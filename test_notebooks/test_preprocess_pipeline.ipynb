# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import os
import sys
import pathlib

# Add project root to Python path
project_root = pathlib.Path(os.getcwd()).parent
sys.path.insert(0, str(project_root))

from src.audio_training_breakdown_automation.audio_breakdown import run

# %%
stem_path = r"C:\Users\nikhi\ml_projects\Audio_Samples\Focus\melody stems"

# %%
file_paths = [os.path.join(stem_path, f) for f in os.listdir(stem_path)]

# %%
run(file_paths)
# Out:
# Processed 7 stems into bars.
# Identified 7 melodic stems and 0 harmony stems.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 run(file_paths)
#
# File c:\Users\nikhi\ml_projects\rearrangement_project\src\audio_training_breakdown_automation\audio_breakdown.py:13, in run(stem_paths)
#      11 from src.model_preprocessing.feature_vector_segmentation import extract_feature_matrix
#      12 from src.model_preprocessing.vector_quantisation import vector_quantisation
# ---> 13 from src.model_preprocessing.chunking_transformation import chunking_transformation
#      15 def process_audio_stems(stems: List[str]) -> Dict[str, np.ndarray]:
#      16     """
#      17     Process audio stems into bars with filename tracking.
#      18     """
#
# File c:\Users\nikhi\ml_projects\rearrangement_project\src\audio_training_breakdown_automation\audio_breakdown.py:107, in process_melodic_harmony_groups(melodic_stems, harmony_stems, BARS)
#     106 def process_melodic_harmony_groups(melodic_stems, harmony_stems, BARS):
# --> 107     """ Sort into matrices for each time step representing feature vectors"""
#     108     structure = find_pattern_arrangement(BARS)
#     109     overall_vectors = []
#
# File c:\Users\nikhi\ml_projects\rearrangement_project\src\audio_training_breakdown_automation\audio_breakdown.py:4, in find_pattern_arrangement(BARS)
#       2 from pathlib import Path
#       3 from typing import Dict, List,Tuple
# ----> 4 import os
#       5 import librosa
#       6 import numpy as np
#
# KeyError: 0
